# %%
import sys,copy,os,inspect
if hasattr(sys.modules[__name__], '__file__'):
    _file_name = __file__
else:
    _file_name = inspect.getfile(inspect.currentframe())
CURRENT_FILE_PATH = os.path.dirname(_file_name)
sys.path.append(os.getcwd()+"/./neuronVis")

import sys,os
from skimage import measure,io
import IONData,Scene
import nrrd
from sklearn.cluster import KMeans
import numpy as np
import trimesh
import matplotlib.pyplot as plt

# %%
import shutil
neurons=Scene.scene2List("./resource/total_neuron.nv")
# iondata = IONData.IONData()
file_handle=open('./resource/total_neuron.txt',mode='w')
# for neuron in neurons:
#     file_handle.writelines('D:/project/python/neuron-vis/resource/swc/'+neuron['sampleid']+"/"+neuron['name']+'\n')
# file_handle.close()
for neuron in neurons:
    path='D:/project/python/neuron-vis/resource/swc/'+neuron['sampleid']+"/"+neuron['name']+"isoprojection.json"
    shutil.move(path, 'D:/project/python/neuron-vis/resource/swc/songwei/'+neuron['sampleid']+"_"+neuron['name']+"isoprojection.json")
    
    # iondata
    # iondata.getNeuronTreeByID(neuron['sampleid'],neuron['name'])
