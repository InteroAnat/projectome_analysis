# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.patches as mpatches

# plt.xlabel("Culmen Length (mm)",fontweight ='bold', size=14)
# plt.ylabel("Culmen Depth (mm)", fontweight ='bold',size=14)

# %%
nodeTree = {
    'nodes':[
        {'name':'VPL',
    'children':{'SSp','AUDd','AUDv'}
    },
    {'name':'VPL',
    'children':{'SSs','AUDd'}
    }
    ]
}

# %%
print(nodeTree['nodes'])
# Out:
# [{'name': 'VPL', 'children': {'AUDd', 'SSp', 'AUDv'}}, {'name': 'VPL', 'children': {'AUDd', 'SSs'}}]

# %%
fig, ax = plt.subplots()
ax.set_axis_off()
left, bottom, width, height = (0.31, 0.15, 0.14, 0.7)
rect=mpatches.Rectangle((left,bottom),width,height, 
                        fill=False,
                        color="purple",
                       linewidth=2)
                       #facecolor="red")
plt.gca().add_patch(rect)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
